# %%
import pandas as pd
import openpyxl

# %%
df = pd.read_csv('Canada_candidate_list_before_conversion-done.csv', encoding='utf-8')
df
# Out:
#          Candidate Type  Tier             Location    First Name Last Name  \
# 0    Academia_Professor     1            Vancouver      Dongwook      Yoon
# 1    Academia_Professor     1  Greater Vancouver A       Mi Jung      Park
# 2    Academia_Professor     1            Vancouver      Gene Moo       Lee
# 3    Academia_Professor     1             Montreal         AJung      Moon
# 4    Academia_Professor     1             Waterloo           Soo      Jeon
# ..                  ...   ...                  ...           ...       ...
# 206            Industry     2               Canada         Junho      Song
# 207            Industry     2               Canada       Jungwon      Kang
# 208            Industry     2          Mississauga  David MinWoo      Kong
# 209            Industry     2               Canada        Jaewon      Choi
# 210            Industry     2            Vancouver       Wonmook      Jung
#
#                                              Education  \
# 0    Cornell University, Doctor of Philosophy (Ph.D...
# 1    The University of Texas at Austin, Doctor of P...
# 2    The University of Texas at Austin, Doctor of P...
# 3    The University of British Columbia, Doctor of ...
# 4    University of California, Berkeley, PhD · 2001...
# ..                                                 ...
# 206  Seoul National University, Doctor of Philosoph...
# 207  Korea Advanced Institute of Science and Techno...
# 208  University of Toronto, Bachelor of Applied Sci...
# 209  Hanyang University, Bachelor of Science (BS) ·...
# 210  Yonsei University, Master's degree · 2011 – 20...
#
#                                        Work Experience  \
# 0    Assistant Professor at The University of Briti...
# 1    Assistant Professor at The University of Briti...
# 2    Associate Professor (with tenure) at The Unive...
# 3    Assistant Professor (ECE) at McGill University...
# 4    Associate Professor at University of Waterloo ...
# ..                                                 ...
# 206  2018 cohort, Y Combinator Startup School, Advi...
# 207  Systems Analyst at Thales · 2021 – Present\nRe...
# 208  AI Project Manager at LG AI Research · 2022 – ...
# 209  Tech Lead / Sr. Software Development Engineer ...
# 210  Software Development Engineer at Amazon · 2017...
#
#                                          Current Title Email Address  \
# 0                                  Assistant Professor           NaN
# 1                                  Assistant Professor           NaN
# 2                    Associate Professor (with tenure)           NaN
# 3                            Assistant Professor (ECE)           NaN
# 4                                  Associate Professor           NaN
# ..                                                 ...           ...
# 206  2018 cohort, Y Combinator Startup School, Advi...           NaN
# 207                                    Systems Analyst           NaN
# 208                                 AI Project Manager           NaN
# 209      Tech Lead / Sr. Software Development Engineer           NaN
# 210                      Software Development Engineer           NaN
#
#     Phone Number                                        Profile URL
# 0            NaN                 https://www.linkedin.com/in/dwyoon
# 1            NaN             https://www.linkedin.com/in/mijungpark
# 2            NaN                  https://www.linkedin.com/in/gmlee
# 3            NaN              https://www.linkedin.com/in/ajungmoon
# 4            NaN      https://www.linkedin.com/in/soo-jeon-30b2aa15
# ..           ...                                                ...
# 206          NaN          https://www.linkedin.com/in/junho-song-ai
# 207          NaN  https://www.linkedin.com/in/jungwon-kang-64696...
# 208          NaN  https://www.linkedin.com/in/david-minwoo-kong-...
# 209          NaN               https://www.linkedin.com/in/cmdrkeen
# 210          NaN            https://www.linkedin.com/in/wonmookjung
#
# [211 rows x 11 columns]

# %%
# df = pd.read_excel('previous_edu_and_exp.xlsx')
# df

# %%
# df = pd.read_csv('previous_edu_and_exp.txt', delimiter = '\t', encoding='utf-8')
# df

# %%
# Replace carriage returns + line feeds with just line feeds
df.Education = df.Education.str.replace('\r\n', '\n')
df['Work Experience'] = df['Work Experience'].str.replace('\r\n', '\n')

# Replace carriage returns with just line feeds
df.Education = df.Education.str.replace('\r', '\n')
df['Work Experience'] = df['Work Experience'].str.replace('\r', '\n')

# %%
# s = df.loc[2, 'Work Experience']
# s

# %%
# exp_list = s.split('\n')
# exp_list

# %%
# title_split_list = exp_list[0].split(' at ', 1)
# title = title_split_list[0]

# %%
# company, period = title_split_list[1].split(' · ')

# %%
# exp_split_list =[title, company, period]
# exp_split_list

# %%
# full_exp_split_list = []
# for exp in exp_list:
#     title_split_list = exp.split(' at ', 1)
#     title = title_split_list[0]
#     company, period = title_split_list[1].rsplit(' · ', 1)
#     exp_split_list = [title, company, period]
#     full_exp_split_list.append(exp_split_list)

# full_exp_split_list

# %%
# exp_string = ''
# full_exp_split_list[0]

# %%
# # Case of single entry for a company
# exp_string + '- ' + full_exp_split_list[0][1] + ', ' + full_exp_split_list[0][0] + ' (' + full_exp_split_list[0][2] + ')'

# %%
# # Case of the same company in next item
# (exp_string + '- ' + full_exp_split_list[0][1] + '\n' +
# '  · ' + full_exp_split_list[0][0] + ' (' + full_exp_split_list[0][2] + ')')

# %%
# Initiate string to hold all the work experiences
# exp_string = ''

# for idx, exp in enumerate(full_exp_split_list):  
#     # Handle the first experience in the list
#     if idx == 0:
#             exp_string = exp_string + '- ' + exp[1] + '\n' + '  · ' + exp[0] + ' (' + exp[2] + ')'
    
#     # Handle the last experience in the list
#     elif idx == len(full_exp_split_list)-1:
#         if full_exp_split_list[idx][1] == full_exp_split_list[idx-1][1]: # current and previous company check
#             new_string = '  · ' + exp[0] + ' (' + exp[2] + ')'
#             exp_string = exp_string + '\n' + new_string
#         else:
#             new_string = '- ' + exp[1] + '\n' + '  · ' + exp[0] + ' (' + exp[2] + ')'
#             exp_string = exp_string + '\n' + new_string
    
#     # Handle all the experiences in the middle
#     else:
#         if full_exp_split_list[idx][1] == full_exp_split_list[idx-1][1]: # current and previous company check
#             new_string = '  · ' + exp[0] + ' (' + exp[2] + ')'
#             exp_string = exp_string + '\n' + new_string
#         else:
#             if full_exp_split_list[idx][1] == full_exp_split_list[idx+1][1]: # current and next company check
#                 new_string = '- ' + exp[1] + '\n' + '  · ' + exp[0] + ' (' + exp[2] + ')'
#                 exp_string = exp_string + '\n' + new_string
#             else:
#                 new_string = '- ' + exp[1] + '\n' + '  · ' + exp[0] + ' (' + exp[2] + ')'
#                 exp_string = exp_string + '\n' + new_string
            
    
# print(exp_string)
#     current_exp = exp
#     next_exp = exp + 1
#     if current_exp[1] == next_exp[1]:
#         next_exp_check = True
#     else:
#         next_exp_check = False
    
#     if multi_exp_flag:
#         exp_string + '- ' + exp[1] + '\n' + '  · ' + exp[0] + ' (' + exp[2] + ')'
#     else:
#         exp_string + '- ' + exp[1] + ', ' + exp[0] + ' (' + exp[2] + ')'
    
#     if next_exp_check == False:
#         multi_exp_flag = False

# %%
# Create experience formatter function
def format_exp (input_exp_string):
    """Takes the work experience input string 
    and puts into a more reader friendly format.
    """
    
    # Split the work experience string into a list at each new line
    exp_list = input_exp_string.split('\n')
    
    # For each experience in the experience list, 
    # pull out the title, company, and period and put them in a list, 
    # then append each list to a full experience list, 
    # creating a nested list.
    full_exp_split_list = []
    
    try:
        for exp in exp_list:
            # Handle cases of "Profile experience" being copied over in the string.
            if exp == "Profile experience":
                print('Warning:\nThe text string \"Profile experience\" was found in one of the work experience entries. ' +
                      'This string is sometimes inadvertently copied over with the experiences when cutting and pasting. ' +
                      'You will need to check all work experience entries in your output file and remove it.\n')
                full_exp_split_list.append(exp)
            else:
                title_split_list = exp.split(' at ', 1)
                title = title_split_list[0]
                company, period = title_split_list[1].rsplit(' · ', 1)
                exp_split_list = [title, company, period]
                full_exp_split_list.append(exp_split_list)
    except IndexError:
        print ('Warning:\nThere is an entry in one of the work experiences that is not in the proper format. ' +
               'All experiences must be in the form [title] at [company] · [period]. ' +
               'Any entries that are not in the proper format will appear as blank cells in the returned file.\n')
    
    # Rebuild the work experience string (exp_string) in a more readable way
    exp_string = ''

    for idx, exp in enumerate(full_exp_split_list):  
        # Format the first experience in the list and add them to the new string
        if idx == 0:
            if exp == 'Profile experience':
                exp_string = exp_string + exp
            else:
                exp_string = exp_string + '- ' + exp[1] + '\n' + '  · ' + exp[0] + ' (' + exp[2] + ')'
        
        # Format all other experiences in the list and add them to the new string
        else:
            if full_exp_split_list[idx][1] == full_exp_split_list[idx-1][1]: # current and previous company check
                new_string = '  · ' + exp[0] + ' (' + exp[2] + ')'
                exp_string = exp_string + '\n' + new_string
            else:
                new_string = '- ' + exp[1] + '\n' + '  · ' + exp[0] + ' (' + exp[2] + ')'
                exp_string = exp_string + '\n' + new_string
                
    return exp_string
#         # Handle the last experience in the list
#         elif idx == len(full_exp_split_list)-1:
#             if full_exp_split_list[idx][1] == full_exp_split_list[idx-1][1]: # current and previous company check
#                 new_string = '  · ' + exp[0] + ' (' + exp[2] + ')'
#                 exp_string = exp_string + '\n' + new_string
#             else:
#                 new_string = '- ' + exp[1] + '\n' + '  · ' + exp[0] + ' (' + exp[2] + ')'
#                 exp_string = exp_string + '\n' + new_string

#         # Handle all the experiences in the middle
#         else:
#             if full_exp_split_list[idx][1] == full_exp_split_list[idx-1][1]: # current and previous company check
#                 new_string = '  · ' + exp[0] + ' (' + exp[2] + ')'
#                 exp_string = exp_string + '\n' + new_string
#             else:
#                 if full_exp_split_list[idx][1] == full_exp_split_list[idx+1][1]: # current and next company check
#                     new_string = '- ' + exp[1] + '\n' + '  · ' + exp[0] + ' (' + exp[2] + ')'
#                     exp_string = exp_string + '\n' + new_string
#                 else:
#                     new_string = '- ' + exp[1] + '\n' + '  · ' + exp[0] + ' (' + exp[2] + ')'
#                     exp_string = exp_string + '\n' + new_string

# %%
df['Work Experience'] = df['Work Experience'].apply(format_exp)
# Out:
# Warning:
# The text string "Profile experience" was found in one of the work experience entries. This string is sometimes inadvertently copied over with the experiences when cutting and pasting. You will need to check all work experience entries in your output file and remove it.

# %%
print(df.loc[3,'Work Experience'])
# Out:
# - McGill University
#   · Assistant Professor (ECE) (2019 – Present)
# - Open Roboethics Institute
#   · Director (2017 – Present)
# - IEEE Global Initiative for Ethical Considerations in Artificial Intelligence and Autonomous Systems
#   · Executive Member (2016 – Present)
# - International Panel on the Regulation of Autonomous Weapons (iPRAW)
#   · Member (2017 – Present)
# - Robohub
#   · Contributor (2012 – Present)
# - Secretariat of the UN Secretary General's High-level Panel on Digital Cooperation
#   · Senior Advisor (2018 – 2019)
# - Generation R Consulting
#   · CEO (2017 – 2019)
# - The University of British Columbia
#   · PhD / Research Assistant (2012 – 2017)
# - Open Roboethics initiative (ORi)
#   · Co-Founder (2012 – 2017)
# - EPFL (École polytechnique fédérale de Lausanne)
#   · Visiting PHD Student (2015 – 2016)
# - University of British Columbia
#   · MASc / Research Assistant (2009 – 2012)
# - Korean Roboethics Charter Committee
#   · Translator (2009 – 2009)
# - University of Waterloo
#   · Research Assistant (2008 – 2008)
# - Toyota
#   · Paint Engineering (2007 – 2007)
# - Prodomax Automation
#   · Controls Specialist (2006 – 2006)
# - Cognos
#   · Query and Reporting QC Analyst (2005 – 2005)
# - General Electric
#   · Hydrogenerator Student Engineer (2005 – 2005)

# %%
# s_edu = df.loc[2, 'Education']
# s_edu

# %%
# edu_list = s_edu.split('\n')
# edu_list

# %%
# Initiate string to hold all the education
# edu_string = ''

# for idx, edu in enumerate(edu_list):
#     if (',' in edu) and ('·' in edu): # All parts of the education list exist
#         school, degree_period_list = edu.rsplit(', ', 1) # rsplit used to account for comma in school name case
#         degree, period = degree_period_list.split(' · ')
#         if idx == 0:
#             edu_string = edu_string + '- ' + degree + ': ' + school +  ' (' + period + ')'
#         else:
#             edu_string = edu_string + '\n' + '- ' + degree + ': ' + school +  ' (' + period + ')'
    
#     elif (',' in edu) and ('·' not in edu): # The school and degree exist, but not the period
#         school, degree = edu.rsplit(', ', 1) # rsplit used to account for comma in school name case
#         if idx == 0:
#             edu_string = edu_string + '- ' + degree + ': ' + school +  ' (????)'
#         else:
#             edu_string = edu_string + '\n' + '- ' + degree + ': ' + school +  ' (????)'
        
#     elif (',' not in edu) and ('·' in edu): # The school and period exist, but not the degree
#         school, period = edu.split(' · ')
#         if idx == 0:
#             edu_string = edu_string + '- '  + '??: ' + school +  ' (' + period + ')'
#         else:
#             edu_string = edu_string + '\n' + '- ' + '??: ' + school +  ' (' + period + ')'
    
#     else: # Only the school exists (this is the only required field for education in LinkedIn)
#         school = edu
#         if idx == 0:
#             edu_string = edu_string + '- ' + '??: ' + school +  ' (????)'
#         else:
#             edu_string = edu_string + '\n' + '- '+ '??: ' + school +  ' (????)'

# print(edu_string)

# %%
# Create education formatter function
def format_edu (input_edu_string):
    """Takes the education input string 
    and puts into a more reader friendly format.
    """
    # Split the education string into a list at each new line
    edu_list = input_edu_string.split('\n')
    
    # Initiate a string to hold all the education in a new format
    edu_string = ''
    
    # Rebuild the education string (edu_string) in a more readable way
    # Note that for education 'school' is the only required field, others are optional
    # So, if the optional fields are missing, question marks (?) will be added to indicate that
    # It seems that there are some rare cases in which only the period is listed, these will be skipped and a message printed
    # Also, if someone uses an unlisted school name then only the degree and period exist,
    # which results in a having just the degree and period listed but with the degree where the school name should be
    for idx, edu in enumerate(edu_list):
        # Print a warning if "Profile education" is present in the education entry.
        if edu == "Profile education":
            print('Warning:\nThe text string \"Profile education\" was found in one of the education entries. ' +
                  'This string is sometimes inadvertently copied over with the education when cutting and pasting. ' +
                  'You will need to check all education entries in your output file and remove it.\n')
        
        if (',' in edu) and ('·' in edu): # All parts of the education list exist
            school, degree_period_list = edu.rsplit(', ', 1) # rsplit used to account for comma in school name case
            degree, period = degree_period_list.split(' · ')
            if idx == 0:
                edu_string = edu_string + '- ' + degree + ': ' + school +  ' (' + period + ')'
            else:
                edu_string = edu_string + '\n' + '- ' + degree + ': ' + school +  ' (' + period + ')'

        elif (',' in edu) and ('·' not in edu): # The school and degree exist, but not the period
            school, degree = edu.rsplit(', ', 1) # rsplit used to account for comma in school name case
            if idx == 0:
                edu_string = edu_string + '- ' + degree + ': ' + school +  ' (????)'
            else:
                edu_string = edu_string + '\n' + '- ' + degree + ': ' + school +  ' (????)'

        elif (',' not in edu) and ('·' in edu): # The school and period exist, but not the degree
            # There are some rare cases in which only the degree and period exist
            # In these cases an error is value error results when the split below is performed
            # In these cases we can add it in the proper format when the error is caught
            # This is done by splitting without spaces on the sides of the center dot
            error_flag = False
            try:
                school, period = edu.split(' · ')
            except ValueError:
                error_flag = True
                
            if error_flag:
                period = edu.lstrip('· ')
                if idx == 0:
                    edu_string = edu_string + '- '  + '??' + ': ' + '??' +  ' (' + period + ')'
                else:
                    edu_string = edu_string + '\n' + '- '  + '??' + ': ' + '??' +  ' (' + period + ')'
            
            else:               
                if idx == 0:
                    edu_string = edu_string + '- '  + '??: ' + school +  ' (' + period + ')'
                else:
                    edu_string = edu_string + '\n' + '- ' + '??: ' + school +  ' (' + period + ')'

        else: # Only the school exists
            school = edu
            if idx == 0:
                edu_string = edu_string + '- ' + '??: ' + school +  ' (????)'
            else:
                edu_string = edu_string + '\n' + '- '+ '??: ' + school +  ' (????)'
        
    return edu_string

# %%
df['Education'] = df['Education'].apply(format_edu)
# Out:
# Warning:
# The text string "Profile education" was found in one of the education entries. This string is sometimes inadvertently copied over with the education when cutting and pasting. You will need to check all education entries in your output file and remove it.

# %%
print(df.loc[7,'Education'])
# Out:
# - Doctor of Philosophy - PhD: University of Toronto (2018 – 2022)
# - Master of Science - MS: Texas A&M University (2014 – 2016)
# - Bachelor's degree: Hanyang University (2008 – 2014)

# %%
df
# Out:
#          Candidate Type  Tier             Location    First Name Last Name  \
# 0    Academia_Professor     1            Vancouver      Dongwook      Yoon
# 1    Academia_Professor     1  Greater Vancouver A       Mi Jung      Park
# 2    Academia_Professor     1            Vancouver      Gene Moo       Lee
# 3    Academia_Professor     1             Montreal         AJung      Moon
# 4    Academia_Professor     1             Waterloo           Soo      Jeon
# ..                  ...   ...                  ...           ...       ...
# 206            Industry     2               Canada         Junho      Song
# 207            Industry     2               Canada       Jungwon      Kang
# 208            Industry     2          Mississauga  David MinWoo      Kong
# 209            Industry     2               Canada        Jaewon      Choi
# 210            Industry     2            Vancouver       Wonmook      Jung
#
#                                              Education  \
# 0    - Doctor of Philosophy (Ph.D.): Cornell Univer...
# 1    - Doctor of Philosophy (Ph.D.): The University...
# 2    - Doctor of Philosophy (Ph.D.): The University...
# 3    - Doctor of Philosophy - PhD: The University o...
# 4    - PhD: University of California, Berkeley (200...
# ..                                                 ...
# 206  - Doctor of Philosophy (Ph.D.) Candidate (ABD)...
# 207  - Doctor of Philosophy (Ph.D.): Korea Advanced...
# 208  - Bachelor of Applied Science - BASc: Universi...
# 209  - Bachelor of Science (BS): Hanyang University...
# 210  - Master's degree: Yonsei University (2011 – 2...
#
#                                        Work Experience  \
# 0    - The University of British Columbia\n  · Assi...
# 1    - The University of British Columbia\n  · Assi...
# 2    - The University of British Columbia\n  · Asso...
# 3    - McGill University\n  · Assistant Professor (...
# 4    - University of Waterloo\n  · Associate Profes...
# ..                                                 ...
# 206  - Y Combinator Startup School\n  · 2018 cohort...
# 207  - Thales\n  · Systems Analyst (2021 – Present)...
# 208  - LG AI Research\n  · AI Project Manager (2022...
# 209  - Amazon\n  · Tech Lead / Sr. Software Develop...
# 210  - Amazon\n  · Software Development Engineer (2...
#
#                                          Current Title Email Address  \
# 0                                  Assistant Professor           NaN
# 1                                  Assistant Professor           NaN
# 2                    Associate Professor (with tenure)           NaN
# 3                            Assistant Professor (ECE)           NaN
# 4                                  Associate Professor           NaN
# ..                                                 ...           ...
# 206  2018 cohort, Y Combinator Startup School, Advi...           NaN
# 207                                    Systems Analyst           NaN
# 208                                 AI Project Manager           NaN
# 209      Tech Lead / Sr. Software Development Engineer           NaN
# 210                      Software Development Engineer           NaN
#
#     Phone Number                                        Profile URL
# 0            NaN                 https://www.linkedin.com/in/dwyoon
# 1            NaN             https://www.linkedin.com/in/mijungpark
# 2            NaN                  https://www.linkedin.com/in/gmlee
# 3            NaN              https://www.linkedin.com/in/ajungmoon
# 4            NaN      https://www.linkedin.com/in/soo-jeon-30b2aa15
# ..           ...                                                ...
# 206          NaN          https://www.linkedin.com/in/junho-song-ai
# 207          NaN  https://www.linkedin.com/in/jungwon-kang-64696...
# 208          NaN  https://www.linkedin.com/in/david-minwoo-kong-...
# 209          NaN               https://www.linkedin.com/in/cmdrkeen
# 210          NaN            https://www.linkedin.com/in/wonmookjung
#
# [211 rows x 11 columns]

# %%
# Add an initial quote at the start of each education and experience
# So that excel recognizes them as text not formulas
def add_quote(input_string):
    input_string = '\'' + input_string
    return input_string

df['Education'] = df['Education'].apply(add_quote)
df['Work Experience'] = df['Work Experience'].apply(add_quote)

df.to_excel('canada_list_output.xlsx', encoding='utf-8')

# %%
# Extra commas in school names have been accounted for
# However commas in degree names could still mess up the formatting
# Note that for education 'school' is the only required field, others are optional
# So, if the optional fields are missing, question marks (?) will be added to indicate that
# It seems that there are some rare cases in which only the period is listed, these will be skipped and a message printed
# Also, if someone uses an unlisted school name then only the degree and period exist,
# which results in a having just the degree and period listed but with the degree where the school name should be

# %%
print(df.loc[13].Education)
# Out:
# '- Doctor of Philosophy (Ph.D.): Simon Fraser University (2016 – 2019)
# - Master's: Korea Advanced Institute of Science and Technology (2002 – 2004)
# - Bachelor of Engineering: Pohang University of Science and Technology (1997 – 2002)
# - Exchange Student: University of Maryland (1999)
# - ??: ?? (1994 – 1997)
